# %% [markdown]
# # Uploading data to googe colab
#
# We will use our data this semster, there are several ways to upload and use your data in google colab
#
# 1. From google drive -- explore the built in  left panel  of google colab
# 2. with wget
# 3. with cloning of github repositories

# %%
#@title Google colab mounting
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Like the other desktop environment you can also access most of the bash command with a `!` added in the front of the command.

# %%
# !pwd
# Out:
# /content

# %%
# !ls -l
# Out:
# total 8
# drwx------ 6 root root 4096 Sep 28 18:13 drive
# drwxr-xr-x 1 root root 4096 Sep 25 18:24 sample_data

# %%
# !ls ./drive/
# Out:
# MyDrive  Othercomputers

# %% [markdown]
# We can download data with wget, here's an example:

# %%
# !wget 'https://raw.githubusercontent.com/prokudin/PHYS496-Fall2024/refs/heads/main/Tutorials/data/gluon_NNPDF31_nlo_pch_as_0118_xmin1e-3.dat'
# Out:
# --2024-09-28 18:14:12--  https://raw.githubusercontent.com/prokudin/PHYS496-Fall2024/refs/heads/main/Tutorials/data/gluon_NNPDF31_nlo_pch_as_0118_xmin1e-3.dat
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39171 (38K) [text/plain]
# Saving to: ‘gluon_NNPDF31_nlo_pch_as_0118_xmin1e-3.dat’
#
# gluon_NNPDF31_nlo_p 100%[===================>]  38.25K  --.-KB/s    in 0.009s
#
# 2024-09-28 18:14:12 (4.28 MB/s) - ‘gluon_NNPDF31_nlo_pch_as_0118_xmin1e-3.dat’ saved [39171/39171]

# %% [markdown]
# We can also clone our github repository https://github.com/prokudin/PHYS496-Fall2024

# %%
# !git clone https://github.com/prokudin/PHYS496-Fall2024.git
# Out:
# Cloning into 'PHYS496-Fall2024'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 41 (delta 4), reused 34 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (41/41), 35.16 MiB | 37.54 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
# !ls -l
# Out:
# total 52
# drwx------ 6 root root  4096 Sep 28 18:13 drive
# -rw-r--r-- 1 root root 39171 Sep 28 18:14 gluon_NNPDF31_nlo_pch_as_0118_xmin1e-3.dat
# drwxr-xr-x 7 root root  4096 Sep 28 18:14 PHYS496-Fall2024
# drwxr-xr-x 1 root root  4096 Sep 25 18:24 sample_data

# %% [markdown]
# Now let us load the data into a pandas data frame

# %%
import pandas as pd

filename1='./PHYS496-Fall2024/Tutorials/data/gluon_NNPDF31_nlo_pch_as_0118_xmin1e-3.dat'
# Headers to skip
lines_to_skip = 5

# Defining the columns (cv = central value, sd = standard deviation)
columns=["x", "gluon_cv", "gluon_sd"]

# read data and create a dataframe
df = pd.read_csv(filename1,
                 sep="\s+",
                 skiprows=lines_to_skip,
                 usecols=[0,1,2],
                 names=columns)

# %%
df.head()
# Out:
#           x  gluon_cv  gluon_sd
# 0  0.001000  4.480675  0.523964
# 1  0.001007  4.478519  0.520743
# 2  0.001014  4.476361  0.517539
# 3  0.001021  4.474202  0.514349
# 4  0.001028  4.472040  0.511176
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['x'].plot(kind='hist', bins=20, title='x')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['gluon_cv'].plot(kind='hist', bins=20, title='gluon_cv')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['gluon_sd'].plot(kind='hist', bins=20, title='gluon_sd')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...
